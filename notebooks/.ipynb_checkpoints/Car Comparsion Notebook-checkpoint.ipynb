# %% [markdown]
# # Car Comparison

# %% [markdown]
# ## Gather the data

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib as plt
import re, os, errno, glob

# %%
# get all csv files in the input folder
all_csv_files = glob.glob("input/*.csv")

# create a dataframe for each csv and then concatenate
# into a single dataframe
df_from_each_file = (pd.read_csv(f) for f in all_csv_files)
car_data = pd.concat(df_from_each_file, ignore_index=True)

# %%
# let's take a look at our data
car_data.head()
# Out:
#     make model  year    city highway fuel tank capacity  \
# 0  Acura   SLX  1999  15 mpg  19 mpg           22.5gal.
# 1  Acura   MDX  2018  18 mpg  26 mpg           19.5gal.
# 2  Acura   MDX  2017  18 mpg  26 mpg           19.5gal.
# 3  Acura   MDX  2016  18 mpg  26 mpg           19.5gal.
# 4  Acura   MDX  2015     NaN     NaN           19.5gal.
#
#    total seating capacity max cargo capacity  \
# 0                     5.0          90 cu.ft.
# 1                     7.0          91 cu.ft.
# 2                     7.0          91 cu.ft.
# 3                     7.0          68 cu.ft.
# 4                     NaN                NaN
#
#                                        drive type cylinder configuration  \
# 0                                      four-wheel                    v-6
# 1                          sh-awd all-wheel drive                    v-6
# 2                          sh-awd all-wheel drive                    v-6
# 3  super handling all-wheel drive all-wheel drive                    v-6
# 4  super handling all-wheel drive all-wheel drive                    v-6
#
#    engine liters        horsepower       transmission                  torque  \
# 0            3.5  215hp @ 5,400rpm  4 speed automatic  230 lb.-ft. @ 3,000rpm
# 1            3.5  290hp @ 6,200rpm  9 speed automatic  267 lb.-ft. @ 4,700rpm
# 2            3.5  290hp @ 6,200rpm  9 speed automatic  267 lb.-ft. @ 4,700rpm
# 3            3.5  290hp @ 6,200rpm  9 speed automatic  267 lb.-ft. @ 4,700rpm
# 4            3.5  290hp @ 6,200rpm  6 speed automatic  267 lb.-ft. @ 4,500rpm
#
#        abs   size
# 0  4-wheel  3.5 l
# 1  4-wheel  3.5 l
# 2  4-wheel  3.5 l
# 3  4-wheel  3.5 l
# 4      NaN    NaN

# %%
# we're going to need to clean up the data and turn it into
# numbers (it came in as strings). this is a method to do so
def cleanDataframe(dataframe, column_names, units):
    
    # create a new dataframe
    new_dataframe = dataframe.loc[:]
    for column in column_names:
        
        # keep only digits
        for unit in units:
            new_dataframe[column] = new_dataframe[column].map(lambda x: str(x).strip(unit))
        
        # change nans to -1s
        new_dataframe[column] = new_dataframe[column].map(lambda x: -1 if x == 'nan' else x)
        
        # change the column to a numeric dtype
        new_dataframe[column] = pd.to_numeric(new_dataframe[column])
        
         # change all -1s (nans) to negative max of column (weight poorly) - comment
        # this out if you want to see all results regardless of how spotty
        # the data might be
        # from https://stackoverflow.com/questions/50773107/how-to-replace-infinite-value-with-maximum-value-of-a-pandas-column
        mask = new_dataframe[column] != -1
        new_dataframe.loc[~mask, column] = -float(new_dataframe.loc[mask, column].max())
        
    # return the new, clean dataframe
    return new_dataframe

# %%
# a method to get the top n in a category
def getTopN(dataframe, column_name, n):
    
    # locate the correct column
    column = dataframe[column_name]
    
    # get the n largest entries
    largest = column.nlargest(10)
    
    # get the indices of the rows
    indices = largest.index.values.tolist()
    
    # re-index into the main dataframe
    # and return the results
    return dataframe.iloc[indices]

# %% [markdown]
# ## Clean up the dataset

# %%
def checkNans(dataframe, column_names):
    for column in column_names:
        nans = dataframe[column].isnull().sum()
        total_rows = dataframe.shape[0]
        print('%s out of %s rows in the column \'%s\' are NaNs' % (nans, total_rows, column))

# %%
checkNans(car_data, interesting_columns)
# Out:
# 905 out of 1143 rows in the column 'city' are NaNs
# 905 out of 1143 rows in the column 'highway' are NaNs
# 0 out of 1143 rows in the column 'fuel tank capacity' are NaNs
# 897 out of 1143 rows in the column 'max cargo capacity' are NaNs

# %% [markdown]
# So only about 250 rows have mpg, and about the same number have max cargo capacity. All listings have fuel tank capacity. How should we deal with NaNs in our data? These are essentially holes in the data. We have two simple options. One is to just make the NaN values 0. In this case they would not really impact our results, and there would be no penalty for lacking data. This would likely make vehicles that are strong in one or two categories and lacking data in the rest rise to the top when they shouldn't necessarily. I'll opt for giving a penalty to data points that are NaN. To do that, I'll take the maximum of each column and insert its negation wherever I see a NaN.

# %%
# the units array is strings that must be removed from the interesting
# columns to isolate the numeric values in the columns. For instance,
# if a value in one of the columns is 'foo 387 gal.', we would need to make sure
# both 'foo' and 'gal.' (note the period) are in the units array
units = ['mpg', 'gal.', 'cu.ft.']
interesting_columns = ['city', 'highway', 'fuel tank capacity', 'max cargo capacity']

# clean up the data
car_data = cleanDataframe(car_data, interesting_columns, units)

# %% [markdown]
# ## Basic Statistics
# We'll run some basic statistics just to see what the best cars in each category are.

# %% [markdown]
# ### What's the top ten cars in terms of cargo space?

# %%
getTopN(car_data, 'max cargo capacity', 10)
# Out:
#           make          model  year  city  highway  fuel tank capacity  \
# 255  Chevrolet  Suburban 1500  1999  14.0     18.0                42.0
# 270  Chevrolet  Suburban 2500  1999 -52.0    -49.0                42.0
# 433        GMC  Suburban 2500  1999 -52.0    -49.0                42.0
# 279   Chrysler       Pacifica  2019  18.0     28.0                19.0
# 280   Chrysler       Pacifica  2018  18.0     28.0                19.0
# 281   Chrysler       Pacifica  2017  19.0     28.0                19.0
# 363       Ford  Expedition EL  2017  15.0     20.0                34.0
# 364       Ford  Expedition EL  2016  15.0     21.0                34.0
# 235  Chevrolet       Suburban  2019  16.0     23.0                31.0
# 236  Chevrolet       Suburban  2018  16.0     23.0                31.0
#
#      total seating capacity  max cargo capacity   drive type  \
# 255                     3.0               150.0   rear-wheel
# 270                     3.0               150.0   rear-wheel
# 433                     3.0               150.0   rear-wheel
# 279                     7.0               140.0  front-wheel
# 280                     7.0               140.0  front-wheel
# 281                     7.0               140.0  front-wheel
# 363                     8.0               131.0   rear-wheel
# 364                     8.0               131.0   rear-wheel
# 235                     8.0               122.0   rear-wheel
# 236                     8.0               122.0   rear-wheel
#
#     cylinder configuration  engine liters        horsepower  \
# 255                    v-8            6.5  195hp @ 3,400rpm
# 270                    v-8            6.5  195hp @ 3,400rpm
# 433                    v-8            6.5  195hp @ 3,400rpm
# 279                    v-6            3.6  287hp @ 6,400rpm
# 280                    v-6            3.6  287hp @ 6,400rpm
# 281                    v-6            3.6  287hp @ 6,400rpm
# 363                    v-6            3.5  365hp @ 5,000rpm
# 364                    v-6            3.5  365hp @ 5,000rpm
# 235                    v-8            5.3  355hp @ 5,600rpm
# 236                    v-8            5.3  355hp @ 5,600rpm
#
#           transmission                  torque      abs   size
# 255  4 speed automatic  430 lb.-ft. @ 1,800rpm  4-wheel  5.7 l
# 270  4 speed automatic  430 lb.-ft. @ 1,800rpm  4-wheel  5.7 l
# 433  4 speed automatic  430 lb.-ft. @ 1,800rpm  4-wheel  5.7 l
# 279  9 speed automatic  262 lb.-ft. @ 4,000rpm  4-wheel  3.6 l
# 280  9 speed automatic  262 lb.-ft. @ 4,000rpm  4-wheel  3.6 l
# 281  9 speed automatic  262 lb.-ft. @ 4,000rpm  4-wheel  3.6 l
# 363  6 speed automatic  420 lb.-ft. @ 2,500rpm  4-wheel  3.5 l
# 364  6 speed automatic  420 lb.-ft. @ 2,500rpm  4-wheel  3.5 l
# 235  6 speed automatic  383 lb.-ft. @ 4,100rpm  4-wheel  5.3 l
# 236  6 speed automatic  383 lb.-ft. @ 4,100rpm  4-wheel  5.3 l

# %% [markdown]
# ### What about MPG?

# %% [markdown]
# #### City MPG

# %%
getTopN(car_data, 'city', 10)
# Out:
#          make              model  year  city  highway  fuel tank capacity  \
# 639       Kia               Niro  2018  52.0     49.0                11.9
# 889    Nissan              Kicks  2018  31.0     36.0                10.8
# 1066   Toyota  Highlander Hybrid  2018  30.0     28.0                17.2
# 1067   Toyota  Highlander Hybrid  2017  30.0     28.0                17.2
# 766     Mazda               CX-3  2019  29.0     34.0                12.7
# 767     Mazda               CX-3  2018  29.0     34.0                12.7
# 909    Nissan      Murano Hybrid  2016  28.0     31.0                19.0
# 523   Hyundai               Kona  2018  27.0     33.0                13.2
# 1038   Toyota               C-HR  2019  27.0     31.0                13.2
# 1039   Toyota               C-HR  2018  27.0     31.0                13.2
#
#       total seating capacity  max cargo capacity       drive type  \
# 639                      5.0                54.0      front-wheel
# 889                      5.0                32.0      front-wheel
# 1066                     8.0                84.0  all-wheel drive
# 1067                     8.0                84.0  all-wheel drive
# 766                      5.0                44.0      front-wheel
# 767                      5.0                44.0      front-wheel
# 909                      5.0                70.0      front-wheel
# 523                      5.0                46.0      front-wheel
# 1038                     5.0                36.0      front-wheel
# 1039                     5.0                36.0      front-wheel
#
#      cylinder configuration  engine liters        horsepower  \
# 639                     i-4            1.6  104hp @ 5,700rpm
# 889                     i-4            1.6  125hp @ 5,800rpm
# 1066                    v-6            3.5  231hp @ 5,800rpm
# 1067                    v-6            3.5  231hp @ 5,800rpm
# 766                     i-4            2.0  148hp @ 6,000rpm
# 767                     i-4            2.0  146hp @ 6,000rpm
# 909                     i-4            2.5  230hp @ 5,600rpm
# 523                     i-4            2.0  147hp @ 6,200rpm
# 1038                    i-4            2.0  144hp @ 6,100rpm
# 1039                    i-4            2.0  144hp @ 6,100rpm
#
#                            transmission                  torque      abs  \
# 639   6 speed automatic with auto-shift  109 lb.-ft. @ 4,000rpm  4-wheel
# 889     continuously variable automatic  115 lb.-ft. @ 4,000rpm  4-wheel
# 1066    continuously variable automatic  215 lb.-ft. @ 4,800rpm  4-wheel
# 1067    continuously variable automatic  215 lb.-ft. @ 4,800rpm  4-wheel
# 766                   6 speed automatic  146 lb.-ft. @ 2,800rpm  4-wheel
# 767                   6 speed automatic  146 lb.-ft. @ 2,800rpm  4-wheel
# 909     continuously variable automatic  243 lb.-ft. @ 3,600rpm  4-wheel
# 523                   6 speed automatic  132 lb.-ft. @ 4,500rpm  4-wheel
# 1038    continuously variable automatic  139 lb.-ft. @ 3,900rpm  4-wheel
# 1039    continuously variable automatic  139 lb.-ft. @ 3,900rpm  4-wheel
#
#        size
# 639   1.6 l
# 889   1.6 l
# 1066  3.5 l
# 1067  3.5 l
# 766   2.0 l
# 767   2.0 l
# 909   2.5 l
# 523   2.0 l
# 1038  2.0 l
# 1039  2.0 l

# %% [markdown]
# #### Highway MPG

# %%
getTopN(car_data, 'highway', 10)
# Out:
#         make       model  year  city  highway  fuel tank capacity  \
# 639      Kia        Niro  2018  52.0     49.0                11.9
# 889   Nissan       Kicks  2018  31.0     36.0                10.8
# 65       BMW          X1  2015  23.0     34.0                16.6
# 766    Mazda        CX-3  2019  29.0     34.0                12.7
# 767    Mazda        CX-3  2018  29.0     34.0                12.7
# 847     MINI  Countryman  2018  24.0     34.0                16.1
# 121    Buick      Encore  2019  25.0     33.0                14.0
# 122    Buick      Encore  2018  25.0     33.0                14.0
# 492    Honda        CR-V  2016  26.0     33.0                15.3
# 523  Hyundai        Kona  2018  27.0     33.0                13.2
#
#      total seating capacity  max cargo capacity   drive type  \
# 639                     5.0                54.0  front-wheel
# 889                     5.0                32.0  front-wheel
# 65                      5.0                56.0   rear-wheel
# 766                     5.0                44.0  front-wheel
# 767                     5.0                44.0  front-wheel
# 847                     5.0                49.0  front-wheel
# 121                     5.0                48.0  front-wheel
# 122                     5.0                48.0  front-wheel
# 492                     5.0                71.0  front-wheel
# 523                     5.0                46.0  front-wheel
#
#     cylinder configuration  engine liters        horsepower  \
# 639                    i-4            1.6  104hp @ 5,700rpm
# 889                    i-4            1.6  125hp @ 5,800rpm
# 65                     i-4            2.0  240hp @ 5,000rpm
# 766                    i-4            2.0  148hp @ 6,000rpm
# 767                    i-4            2.0  146hp @ 6,000rpm
# 847                    i-3            1.5  134hp @ 4,400rpm
# 121                    i-4            1.4  138hp @ 4,900rpm
# 122                    i-4            1.4  138hp @ 4,900rpm
# 492                    i-4            2.4  185hp @ 6,400rpm
# 523                    i-4            2.0  147hp @ 6,200rpm
#
#                           transmission                  torque      abs   size
# 639  6 speed automatic with auto-shift  109 lb.-ft. @ 4,000rpm  4-wheel  1.6 l
# 889    continuously variable automatic  115 lb.-ft. @ 4,000rpm  4-wheel  1.6 l
# 65                   8 speed automatic  260 lb.-ft. @ 1,450rpm  4-wheel  2.0 l
# 766                  6 speed automatic  146 lb.-ft. @ 2,800rpm  4-wheel  2.0 l
# 767                  6 speed automatic  146 lb.-ft. @ 2,800rpm  4-wheel  2.0 l
# 847                  6 speed automatic  162 lb.-ft. @ 1,250rpm  4-wheel  1.5 l
# 121                  6 speed automatic  148 lb.-ft. @ 1,850rpm  4-wheel  1.4 l
# 122                  6 speed automatic  148 lb.-ft. @ 1,850rpm  4-wheel  1.4 l
# 492    continuously variable automatic  181 lb.-ft. @ 3,900rpm  4-wheel  2.4 l
# 523                  6 speed automatic  132 lb.-ft. @ 4,500rpm  4-wheel  2.0 l

# %% [markdown]
# ## Largest gas tank?

# %%
getTopN(car_data, 'fuel tank capacity', 10)
# Out:
#           make          model  year  city  highway  fuel tank capacity  \
# 337       Ford      Excursion  2005 -52.0    -49.0                44.0
# 338       Ford      Excursion  2004 -52.0    -49.0                44.0
# 339       Ford      Excursion  2003 -52.0    -49.0                44.0
# 340       Ford      Excursion  2002 -52.0    -49.0                44.0
# 341       Ford      Excursion  2001 -52.0    -49.0                44.0
# 342       Ford      Excursion  2000 -52.0    -49.0                44.0
# 255  Chevrolet  Suburban 1500  1999  14.0     18.0                42.0
# 270  Chevrolet  Suburban 2500  1999 -52.0    -49.0                42.0
# 432        GMC  Suburban 1500  1999 -52.0    -49.0                42.0
# 433        GMC  Suburban 2500  1999 -52.0    -49.0                42.0
#
#      total seating capacity  max cargo capacity  drive type  \
# 337                     NaN              -150.0  four-wheel
# 338                     NaN              -150.0  rear-wheel
# 339                     NaN              -150.0  rear-wheel
# 340                     NaN              -150.0  rear-wheel
# 341                     NaN              -150.0  rear-wheel
# 342                     NaN              -150.0  rear-wheel
# 255                     3.0               150.0  rear-wheel
# 270                     3.0               150.0  rear-wheel
# 432                     NaN              -150.0  rear-wheel
# 433                     3.0               150.0  rear-wheel
#
#     cylinder configuration  engine liters        horsepower  \
# 337                    v-8            5.4  255hp @ 4,500rpm
# 338                    v-8            5.4  255hp @ 4,500rpm
# 339                    v-8            5.4  255hp @ 4,500rpm
# 340                    v-8            5.4  255hp @ 4,500rpm
# 341                    v-8            5.4  255hp @ 4,500rpm
# 342                    v-8            5.4  260hp @ 4,500rpm
# 255                    v-8            6.5  195hp @ 3,400rpm
# 270                    v-8            6.5  195hp @ 3,400rpm
# 432                    v-8            6.5  195hp @ 3,400rpm
# 433                    v-8            6.5  195hp @ 3,400rpm
#
#           transmission                  torque      abs   size
# 337  4 speed automatic  350 lb.-ft. @ 2,500rpm      NaN    NaN
# 338  4 speed automatic  350 lb.-ft. @ 2,500rpm      NaN    NaN
# 339  4 speed automatic  350 lb.-ft. @ 2,500rpm      NaN    NaN
# 340  4 speed automatic  350 lb.-ft. @ 2,500rpm      NaN    NaN
# 341  4 speed automatic  350 lb.-ft. @ 2,500rpm      NaN    NaN
# 342  4 speed automatic  350 lb.-ft. @ 2,500rpm      NaN    NaN
# 255  4 speed automatic  430 lb.-ft. @ 1,800rpm  4-wheel  5.7 l
# 270  4 speed automatic  430 lb.-ft. @ 1,800rpm  4-wheel  5.7 l
# 432  4 speed automatic  430 lb.-ft. @ 1,800rpm      NaN    NaN
# 433  4 speed automatic  430 lb.-ft. @ 1,800rpm  4-wheel  5.7 l

# %% [markdown]
# ## Selecting Best Overall

# %% [markdown]
# So that's the raw data. However, we actually need to find the top picks in terms of _all_ these attributes, to the best of our abilities. To do this, we first need to isolate the columns that we're actually interested in

# %%
car_data_subset = car_data[interesting_columns]
car_data_subset.head()
# Out:
#    city  highway  fuel tank capacity  max cargo capacity
# 0  15.0     19.0                22.5                90.0
# 1  18.0     26.0                19.5                91.0
# 2  18.0     26.0                19.5                91.0
# 3  18.0     26.0                19.5                68.0
# 4 -52.0    -49.0                19.5              -150.0

# %%
# we should have no nans
checkNans(car_data_subset, interesting_columns)
# Out:
# 0 out of 1143 rows in the column 'city' are NaNs
# 0 out of 1143 rows in the column 'highway' are NaNs
# 0 out of 1143 rows in the column 'fuel tank capacity' are NaNs
# 0 out of 1143 rows in the column 'max cargo capacity' are NaNs

# %% [markdown]
# ## Vector Comparison
# Now that we have our subset of data that we're interested in, we can simply compare each row as an n-dimensional vector. Let's try finding our most wanted car using unweighted data, simply finding the magnitude of each vector and keeping the largest vectors we find.

# %%
# first we normalize our data - https://stackoverflow.com/questions/26414913/normalize-columns-of-pandas-data-frame/29651514
from sklearn import preprocessing

values = car_data_subset.values # returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
scaled = min_max_scaler.fit_transform(values)
car_data_subset_norm = pd.DataFrame(scaled)

print(car_data_subset_norm.head())

# now that we've normalized the data, let's find the magnitude of each vector
car_data_magnitudes = car_data_subset_norm.apply(lambda x: np.linalg.norm(np.array(x.tolist())), axis=1)
car_data_magnitudes = pd.DataFrame(car_data_magnitudes)

# change the number in nlargest to how many results you want
largest_magnitudes = car_data_magnitudes.nlargest(100, 0)
indices = largest_magnitudes.index.values.tolist()
best_cars = car_data.iloc[indices]

# Check out the normalized version of the data below:
# Out:
#           0         1         2         3
# 0  0.644231  0.693878  0.352410  0.800000
# 1  0.673077  0.765306  0.262048  0.803333
# 2  0.673077  0.765306  0.262048  0.803333
# 3  0.673077  0.765306  0.262048  0.726667
# 4  0.000000  0.000000  0.262048  0.000000

# %%
# take any negative values (the penalized "data holes") and insert NaNs so they don't show up.
for column in interesting_columns:
    best_cars[column] = best_cars[column].map(lambda x: np.nan if float(x) < 0 else x)
best_cars
# Out:
# C:\Users\morom\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                make              model  year  city  highway  \
# 255       Chevrolet      Suburban 1500  1999  14.0     18.0
# 639             Kia               Niro  2018  52.0     49.0
# 364            Ford      Expedition EL  2016  15.0     21.0
# 363            Ford      Expedition EL  2017  15.0     20.0
# 235       Chevrolet           Suburban  2019  16.0     23.0
# 236       Chevrolet           Suburban  2018  16.0     23.0
# 237       Chevrolet           Suburban  2017  16.0     23.0
# 238       Chevrolet           Suburban  2016  16.0     23.0
# 168        Cadillac       Escalade ESV  2019  14.0     23.0
# 169        Cadillac       Escalade ESV  2018  14.0     23.0
# 170        Cadillac       Escalade ESV  2017  15.0     22.0
# 171        Cadillac       Escalade ESV  2016  15.0     22.0
# 281        Chrysler           Pacifica  2017  19.0     28.0
# 374            Ford     Expedition Max  2018  17.0     23.0
# 279        Chrysler           Pacifica  2019  18.0     28.0
# 280        Chrysler           Pacifica  2018  18.0     28.0
# 362            Ford         Expedition  1999  13.0     18.0
# 345            Ford         Expedition  2016  16.0     22.0
# 344            Ford         Expedition  2017  15.0     21.0
# 1066         Toyota  Highlander Hybrid  2018  30.0     28.0
# 1067         Toyota  Highlander Hybrid  2017  30.0     28.0
# 270       Chevrolet      Suburban 2500  1999   NaN      NaN
# 433             GMC      Suburban 2500  1999   NaN      NaN
# 343            Ford         Expedition  2018  17.0     24.0
# 909          Nissan      Murano Hybrid  2016  28.0     31.0
# 467             GMC              Yukon  2019  16.0     23.0
# 468             GMC              Yukon  2018  16.0     23.0
# 469             GMC              Yukon  2017  16.0     23.0
# 470             GMC              Yukon  2016  16.0     23.0
# 977          Subaru            Outback  2018  25.0     32.0
# ...             ...                ...   ...   ...      ...
# 1020         Toyota            4Runner  2016  17.0     22.0
# 1021         Toyota            4Runner  2015  17.0     22.0
# 1022         Toyota            4Runner  2014  17.0     22.0
# 1023         Toyota            4Runner  2013  17.0     22.0
# 65              BMW                 X1  2015  23.0     34.0
# 556        Infiniti               QX50  2019  24.0     31.0
# 910          Nissan         Pathfinder  2018  20.0     27.0
# 564        Infiniti               QX60  2016  21.0     27.0
# 932         Porsche            Cayenne  2018  18.0     24.0
# 434             GMC            Terrain  2019  26.0     30.0
# 435             GMC            Terrain  2018  26.0     30.0
# 457             GMC            Terrain  2019  26.0     30.0
# 458             GMC            Terrain  2018  26.0     30.0
# 782           Mazda               CX-9  2018  22.0     28.0
# 783           Mazda               CX-9  2017  22.0     28.0
# 814   Mercedes-Benz         AMG GLS 63  2017  13.0     17.0
# 318            Ford               Edge  2018  21.0     29.0
# 1018         Toyota            4Runner  2018  17.0     21.0
# 1019         Toyota            4Runner  2017  17.0     21.0
# 399             GMC             Acadia  2019  21.0     26.0
# 400             GMC             Acadia  2018  21.0     26.0
# 444             GMC             Acadia  2019  21.0     26.0
# 445             GMC             Acadia  2018  21.0     26.0
# 914          Nissan         Pathfinder  2014  20.0     26.0
# 915          Nissan         Pathfinder  2013  20.0     26.0
# 50             Audi                 Q7  2015  16.0     22.0
# 51             Audi                 Q7  2014  16.0     22.0
# 52             Audi                 Q7  2013  16.0     22.0
# 642             Kia            Sorento  2018  21.0     28.0
# 770           Mazda               CX-5  2018  25.0     31.0
#
#       fuel tank capacity  total seating capacity  max cargo capacity  \
# 255                 42.0                     3.0               150.0
# 639                 11.9                     5.0                54.0
# 364                 34.0                     8.0               131.0
# 363                 34.0                     8.0               131.0
# 235                 31.0                     8.0               122.0
# 236                 31.0                     8.0               122.0
# 237                 31.0                     8.0               122.0
# 238                 31.0                     8.0               122.0
# 168                 31.0                     7.0               121.0
# 169                 31.0                     7.0               121.0
# 170                 31.0                     7.0               121.0
# 171                 31.0                     7.0               121.0
# 281                 19.0                     7.0               140.0
# 374                 28.3                     5.0               121.0
# 279                 19.0                     7.0               140.0
# 280                 19.0                     7.0               140.0
# 362                 30.0                     9.0               118.0
# 345                 28.0                     5.0               108.0
# 344                 28.0                     5.0               108.0
# 1066                17.2                     8.0                84.0
# 1067                17.2                     8.0                84.0
# 270                 42.0                     3.0               150.0
# 433                 42.0                     3.0               150.0
# 343                 23.3                     5.0               105.0
# 909                 19.0                     5.0                70.0
# 467                 26.0                     8.0                95.0
# 468                 26.0                     8.0                95.0
# 469                 26.0                     8.0                95.0
# 470                 26.0                     8.0                95.0
# 977                 18.5                     5.0                73.0
# ...                  ...                     ...                 ...
# 1020                23.0                     5.0                90.0
# 1021                23.0                     5.0                90.0
# 1022                23.0                     5.0                90.0
# 1023                23.0                     5.0                90.0
# 65                  16.6                     5.0                56.0
# 556                 16.0                     5.0                65.0
# 910                 19.5                     7.0                80.0
# 564                 19.5                     7.0                77.0
# 932                 26.4                     5.0                63.0
# 434                 14.9                     5.0                63.0
# 435                 14.9                     5.0                63.0
# 457                 14.9                     5.0                63.0
# 458                 14.9                     5.0                63.0
# 782                 19.0                     7.0                71.0
# 783                 19.0                     7.0                71.0
# 814                 26.4                     7.0                94.0
# 318                 18.0                     5.0                73.0
# 1018                23.0                     5.0                90.0
# 1019                23.0                     5.0                90.0
# 399                 19.0                     7.0                79.0
# 400                 19.0                     7.0                79.0
# 444                 19.0                     7.0                79.0
# 445                 19.0                     7.0                79.0
# 914                 19.5                     7.0                80.0
# 915                 19.5                     7.0                80.0
# 50                  26.4                     7.0                72.0
# 51                  26.4                     7.0                72.0
# 52                  26.4                     7.0                72.0
# 642                 18.8                     5.0                73.0
# 770                 14.8                     5.0                60.0
#
#                    drive type cylinder configuration  engine liters  \
# 255                rear-wheel                    v-8            6.5
# 639               front-wheel                    i-4            1.6
# 364                rear-wheel                    v-6            3.5
# 363                rear-wheel                    v-6            3.5
# 235                rear-wheel                    v-8            5.3
# 236                rear-wheel                    v-8            5.3
# 237                rear-wheel                    v-8            5.3
# 238                rear-wheel                    v-8            5.3
# 168                rear-wheel                    v-8            6.2
# 169                rear-wheel                    v-8            6.2
# 170                rear-wheel                    v-8            6.2
# 171                rear-wheel                    v-8            6.2
# 281               front-wheel                    v-6            3.6
# 374                rear-wheel                    v-6            3.5
# 279               front-wheel                    v-6            3.6
# 280               front-wheel                    v-6            3.6
# 362                rear-wheel                    v-8            5.4
# 345                rear-wheel                    v-6            3.5
# 344                rear-wheel                    v-6            3.5
# 1066          all-wheel drive                    v-6            3.5
# 1067          all-wheel drive                    v-6            3.5
# 270                rear-wheel                    v-8            6.5
# 433                rear-wheel                    v-8            6.5
# 343                rear-wheel                    v-6            3.5
# 909               front-wheel                    i-4            2.5
# 467                rear-wheel                    v-8            5.3
# 468                rear-wheel                    v-8            5.3
# 469                rear-wheel                    v-8            5.3
# 470                rear-wheel                    v-8            5.3
# 977           all-wheel drive                    h-4            2.5
# ...                       ...                    ...            ...
# 1020               rear-wheel                    v-6            4.0
# 1021               rear-wheel                    v-6            4.0
# 1022               rear-wheel                    v-6            4.0
# 1023               rear-wheel                    v-6            4.0
# 65                 rear-wheel                    i-4            2.0
# 556               front-wheel                    i-4            2.0
# 910               front-wheel                    v-6            3.5
# 564               front-wheel                    v-6            3.5
# 932           all-wheel drive                    v-6            3.6
# 434               front-wheel                    i-4            1.5
# 435               front-wheel                    i-4            1.5
# 457               front-wheel                    i-4            1.5
# 458               front-wheel                    i-4            1.5
# 782               front-wheel                    i-4            2.5
# 783               front-wheel                    i-4            2.5
# 814                    4matic                    v-8            5.5
# 318               front-wheel                    i-4            2.0
# 1018               rear-wheel                    v-6            4.0
# 1019               rear-wheel                    v-6            4.0
# 399               front-wheel                    i-4            2.5
# 400               front-wheel                    i-4            2.5
# 444               front-wheel                    i-4            2.5
# 445               front-wheel                    i-4            2.5
# 914               front-wheel                    v-6            3.5
# 915               front-wheel                    v-6            3.5
# 50    quattro all-wheel drive                    v-6            3.0
# 51    quattro all-wheel drive                    v-6            3.0
# 52    quattro all-wheel drive                    v-6            3.0
# 642               front-wheel                    i-4            2.4
# 770               front-wheel                    i-4            2.5
#
#             horsepower                       transmission  \
# 255   195hp @ 3,400rpm                  4 speed automatic
# 639   104hp @ 5,700rpm  6 speed automatic with auto-shift
# 364   365hp @ 5,000rpm                  6 speed automatic
# 363   365hp @ 5,000rpm                  6 speed automatic
# 235   355hp @ 5,600rpm                  6 speed automatic
# 236   355hp @ 5,600rpm                  6 speed automatic
# 237   355hp @ 5,600rpm                  6 speed automatic
# 238   355hp @ 5,600rpm                  6 speed automatic
# 168   420hp @ 5,600rpm                 10 speed automatic
# 169   420hp @ 5,600rpm                 10 speed automatic
# 170   420hp @ 5,600rpm                  8 speed automatic
# 171   420hp @ 5,600rpm                  8 speed automatic
# 281   287hp @ 6,400rpm                  9 speed automatic
# 374   375hp @ 5,000rpm                 10 speed automatic
# 279   287hp @ 6,400rpm                  9 speed automatic
# 280   287hp @ 6,400rpm                  9 speed automatic
# 362   260hp @ 4,500rpm                  4 speed automatic
# 345   365hp @ 5,000rpm                  6 speed automatic
# 344   365hp @ 5,000rpm                  6 speed automatic
# 1066  231hp @ 5,800rpm    continuously variable automatic
# 1067  231hp @ 5,800rpm    continuously variable automatic
# 270   195hp @ 3,400rpm                  4 speed automatic
# 433   195hp @ 3,400rpm                  4 speed automatic
# 343   375hp @ 5,000rpm                 10 speed automatic
# 909   230hp @ 5,600rpm    continuously variable automatic
# 467   355hp @ 5,600rpm                  6 speed automatic
# 468   355hp @ 5,600rpm                  6 speed automatic
# 469   355hp @ 5,600rpm                  6 speed automatic
# 470   355hp @ 5,600rpm                  6 speed automatic
# 977   175hp @ 5,800rpm    continuously variable automatic
# ...                ...                                ...
# 1020  270hp @ 5,600rpm                  5 speed automatic
# 1021  270hp @ 5,600rpm                  5 speed automatic
# 1022  270hp @ 5,600rpm                  5 speed automatic
# 1023  270hp @ 5,600rpm                  5 speed automatic
# 65    240hp @ 5,000rpm                  8 speed automatic
# 556   268hp @ 5,600rpm    continuously variable automatic
# 910   284hp @ 6,400rpm    continuously variable automatic
# 564   265hp @ 6,400rpm    continuously variable automatic
# 932   300hp @ 6,300rpm                  8 speed automatic
# 434   170hp @ 5,600rpm                  9 speed automatic
# 435   170hp @ 5,600rpm                  9 speed automatic
# 457   170hp @ 5,600rpm                  9 speed automatic
# 458   170hp @ 5,600rpm                  9 speed automatic
# 782   227hp @ 5,000rpm                  6 speed automatic
# 783   227hp @ 5,000rpm                  6 speed automatic
# 814   577hp @ 5,250rpm                  7 speed automatic
# 318   245hp @ 5,500rpm                  6 speed automatic
# 1018  270hp @ 5,600rpm                  5 speed automatic
# 1019  270hp @ 5,600rpm                  5 speed automatic
# 399   193hp @ 6,300rpm                  6 speed automatic
# 400   193hp @ 6,300rpm                  6 speed automatic
# 444   193hp @ 6,300rpm                  6 speed automatic
# 445   193hp @ 6,300rpm                  6 speed automatic
# 914   260hp @ 6,400rpm    continuously variable automatic
# 915   260hp @ 6,400rpm    continuously variable automatic
# 50    280hp @ 4,920rpm                  8 speed automatic
# 51    280hp @ 4,920rpm                  8 speed automatic
# 52    280hp @ 4,920rpm                  8 speed automatic
# 642   185hp @ 6,000rpm                  6 speed automatic
# 770   187hp @ 6,000rpm                  6 speed automatic
#
#                       torque      abs   size
# 255   430 lb.-ft. @ 1,800rpm  4-wheel  5.7 l
# 639   109 lb.-ft. @ 4,000rpm  4-wheel  1.6 l
# 364   420 lb.-ft. @ 2,500rpm  4-wheel  3.5 l
# 363   420 lb.-ft. @ 2,500rpm  4-wheel  3.5 l
# 235   383 lb.-ft. @ 4,100rpm  4-wheel  5.3 l
# 236   383 lb.-ft. @ 4,100rpm  4-wheel  5.3 l
# 237   383 lb.-ft. @ 4,100rpm  4-wheel  5.3 l
# 238   383 lb.-ft. @ 4,100rpm  4-wheel  5.3 l
# 168   460 lb.-ft. @ 4,100rpm  4-wheel  6.2 l
# 169   460 lb.-ft. @ 4,100rpm  4-wheel  6.2 l
# 170   460 lb.-ft. @ 4,100rpm  4-wheel  6.2 l
# 171   460 lb.-ft. @ 4,100rpm  4-wheel  6.2 l
# 281   262 lb.-ft. @ 4,000rpm  4-wheel  3.6 l
# 374   470 lb.-ft. @ 3,500rpm  4-wheel  3.5 l
# 279   262 lb.-ft. @ 4,000rpm  4-wheel  3.6 l
# 280   262 lb.-ft. @ 4,000rpm  4-wheel  3.6 l
# 362   345 lb.-ft. @ 2,300rpm  4-wheel  4.6 l
# 345   420 lb.-ft. @ 2,500rpm  4-wheel  3.5 l
# 344   420 lb.-ft. @ 2,500rpm  4-wheel  3.5 l
# 1066  215 lb.-ft. @ 4,800rpm  4-wheel  3.5 l
# 1067  215 lb.-ft. @ 4,800rpm  4-wheel  3.5 l
# 270   430 lb.-ft. @ 1,800rpm  4-wheel  5.7 l
# 433   430 lb.-ft. @ 1,800rpm  4-wheel  5.7 l
# 343   470 lb.-ft. @ 3,500rpm  4-wheel  3.5 l
# 909   243 lb.-ft. @ 3,600rpm  4-wheel  2.5 l
# 467   383 lb.-ft. @ 4,100rpm  4-wheel  5.3 l
# 468   383 lb.-ft. @ 4,100rpm  4-wheel  5.3 l
# 469   383 lb.-ft. @ 4,100rpm  4-wheel  5.3 l
# 470   383 lb.-ft. @ 4,100rpm  4-wheel  5.3 l
# 977   174 lb.-ft. @ 4,000rpm  4-wheel  2.5 l
# ...                      ...      ...    ...
# 1020  278 lb.-ft. @ 4,400rpm  4-wheel  4.0 l
# 1021  278 lb.-ft. @ 4,400rpm  4-wheel  4.0 l
# 1022  278 lb.-ft. @ 4,400rpm  4-wheel  4.0 l
# 1023  278 lb.-ft. @ 4,400rpm  4-wheel  4.0 l
# 65    260 lb.-ft. @ 1,450rpm  4-wheel  2.0 l
# 556   280 lb.-ft. @ 1,600rpm  4-wheel  2.0 l
# 910   259 lb.-ft. @ 4,400rpm  4-wheel  3.5 l
# 564   248 lb.-ft. @ 4,400rpm  4-wheel  3.5 l
# 932   295 lb.-ft. @ 3,000rpm  4-wheel  3.6 l
# 434   203 lb.-ft. @ 2,000rpm  4-wheel  1.5 l
# 435   203 lb.-ft. @ 2,000rpm  4-wheel  1.5 l
# 457   203 lb.-ft. @ 2,000rpm  4-wheel  1.5 l
# 458   203 lb.-ft. @ 2,000rpm  4-wheel  1.5 l
# 782   310 lb.-ft. @ 2,000rpm  4-wheel  2.5 l
# 783   310 lb.-ft. @ 2,000rpm  4-wheel  2.5 l
# 814   561 lb.-ft. @ 1,750rpm  4-wheel  5.5 l
# 318   275 lb.-ft. @ 3,000rpm  4-wheel  2.0 l
# 1018  278 lb.-ft. @ 4,400rpm  4-wheel  4.0 l
# 1019  278 lb.-ft. @ 4,400rpm  4-wheel  4.0 l
# 399   188 lb.-ft. @ 4,400rpm  4-wheel  2.5 l
# 400   188 lb.-ft. @ 4,400rpm  4-wheel  2.5 l
# 444   188 lb.-ft. @ 4,400rpm  4-wheel  2.5 l
# 445   188 lb.-ft. @ 4,400rpm  4-wheel  2.5 l
# 914   240 lb.-ft. @ 4,400rpm  4-wheel  3.5 l
# 915   240 lb.-ft. @ 4,400rpm  4-wheel  3.5 l
# 50    295 lb.-ft. @ 2,250rpm  4-wheel  3.0 l
# 51    295 lb.-ft. @ 2,250rpm  4-wheel  3.0 l
# 52    295 lb.-ft. @ 2,250rpm  4-wheel  3.0 l
# 642   178 lb.-ft. @ 4,000rpm  4-wheel  2.4 l
# 770   186 lb.-ft. @ 4,000rpm  4-wheel  2.5 l
#
# [100 rows x 16 columns]

# %%
# write the output csv - https://stackoverflow.com/questions/12517451/automatically-creating-directories-with-file-output
output_filename = 'output/best_cars_for_me.csv'
if not os.path.exists(os.path.dirname(output_filename)):
    try:
        os.makedirs(os.path.dirname(output_filename))
    except OSError as exc: # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

best_cars.to_csv(output_filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-615-006e0f5d094a> in <module>()
#       1 # write the output csv
# ----> 2 best_cars.to_csv('output/best_cars_for_me.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
#    1638             close = True
#    1639
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     388         elif encoding:
#     389             # Python 3 and encoding
# --> 390             f = open(path_or_buf, mode, encoding=encoding)
#     391         elif is_text:
#     392             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/best_cars_for_me.csv'
